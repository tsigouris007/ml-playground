# %%
import pandas as pd

# %%
series = pd.Series(["BMW", "Toyota", "Mercedes", "Suzuki", "Opel", "Volkswagen", "Chevrolet", "Hyundai", "Tesla"])

# %%
series
# Out:
# 0           BMW
# 1        Toyota
# 2      Mercedes
# 3        Suzuki
# 4          Opel
# 5    Volkswagen
# 6     Chevrolet
# 7       Hyundai
# 8         Tesla
# dtype: object

# %%
colors = pd.Series(["Red", "Blue", "Black", "White", "Purple", "Pink", "Orange", "Yellow", "Green"])

# %%
colors
# Out:
# 0       Red
# 1      Blue
# 2     Black
# 3     White
# 4    Purple
# 5      Pink
# 6    Orange
# 7    Yellow
# 8     Green
# dtype: object

# %%
car = pd.DataFrame({
    "Brand": series,
    "Color": colors
})

# %%
car
# Out:
#         Brand   Color
# 0         BMW     Red
# 1      Toyota    Blue
# 2    Mercedes   Black
# 3      Suzuki   White
# 4        Opel  Purple
# 5  Volkswagen    Pink
# 6   Chevrolet  Orange
# 7     Hyundai  Yellow
# 8       Tesla   Green

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.to_csv("exported-car-sales.csv", index=False)

# %% [markdown]
# ## Fetch csv data file from Git remote

# %%
git_car_sales = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv")

# %%
git_car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
git_car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
git_car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
git_car_columns = git_car_sales.columns

# %%
git_car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
git_car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
git_car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
git_car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
git_car_sales["Doors"].mean()
# Out:
# 4.0

# %%
git_car_sales.count
# Out:
# <bound method DataFrame.count of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
animals = pd.Series(["cat", "dog", "chicken", "hog", "mouse", "monkey", "zebra", "lion", "tiger"], index=[1, 2, 3, 4, 5, 6, 7, 8, 9])

# %%
animals
# Out:
# 1        cat
# 2        dog
# 3    chicken
# 4        hog
# 5      mouse
# 6     monkey
# 7      zebra
# 8       lion
# 9      tiger
# dtype: object

# %%
animals.loc[4]
# Out:
# 'hog'

# %%
animals.iloc[4]
# Out:
# 'mouse'

# %%
animals = pd.Series(["cat", "dog", "chicken", "hog", "mouse", "monkey", "zebra", "lion", "tiger"], index=[9, 8, 7, 6, 5, 4, 3, 2, 1])

# %%
animals
# Out:
# 9        cat
# 8        dog
# 7    chicken
# 6        hog
# 5      mouse
# 4     monkey
# 3      zebra
# 2       lion
# 1      tiger
# dtype: object

# %%
animals.loc[4]
# Out:
# 'monkey'

# %%
animals.iloc[4]
# Out:
# 'mouse'

# %%
animals.iloc[:3]
# Out:
# 9        cat
# 8        dog
# 7    chicken
# dtype: object

# %%
animals.loc[:3]
# Out:
# 9        cat
# 8        dog
# 7    chicken
# 6        hog
# 5      mouse
# 4     monkey
# 3      zebra
# dtype: object

# %%
git_car_sales[git_car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
git_car_sales[git_car_sales["Odometer (KM)"] > 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
git_car_sales.Price = git_car_sales.Price.str.replace('[$,.]', '', regex=True).astype(int)

# %%
git_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
git_car_sales.Price.mean()
# Out:
# 764500.0

# %%
pd.crosstab(git_car_sales.Make, git_car_sales.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(git_car_sales.Make, git_car_sales.Colour)
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
git_car_sales.groupby(["Make"]).Price.mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
git_car_sales.Make = git_car_sales.Make.str.lower()

# %%
git_car_sales.Make
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales.Odometer.fillna(0, inplace=True)
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_9416\822565549.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales.Odometer.fillna(0, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       0.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       0.0    4.0   $4,500
# 6   Honda    NaN       0.0    4.0   $7,500
# 7   Honda   Blue       0.0    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales.dropna(inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_a = car_sales.dropna()

# %%
car_sales_a
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats_col = pd.Series([5, 5, 5, 5, 5])

# %% [markdown]
# # Column add - Series

# %%
car_sales["Seats"] = seats_col
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    NaN
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
car_sales.Seats.fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    NaN
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %% [markdown]
# # Column add - List

# %%
fuel = [7.5, 9.2, 5.0, 4.5, 8.2, 4.7, 7.6, 3.2, 5.5, 6.2]
car_sales["Fuel per 100KM"] = fuel
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             4.5
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.2
# 5  Toyota  Green       NaN    4.0   $4,500    NaN             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    NaN             7.6
# 7   Honda   Blue       NaN    4.0      NaN    NaN             3.2
# 8  Toyota  White   60000.0    NaN      NaN    NaN             5.5
# 9     NaN  White   31600.0    4.0   $9,700    NaN             6.2

# %% [markdown]
# # Calculate lifetime fuels

# %%
car_sales["Total fuel used"] = car_sales.Odometer / 100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             4.5
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.2
# 5  Toyota  Green       NaN    4.0   $4,500    NaN             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    NaN             7.6
# 7   Honda   Blue       NaN    4.0      NaN    NaN             3.2
# 8  Toyota  White   60000.0    NaN      NaN    NaN             5.5
# 9     NaN  White   31600.0    4.0   $9,700    NaN             6.2
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2              NaN
# 3          503.055
# 4        17473.790
# 5              NaN
# 6              NaN
# 7              NaN
# 8         3300.000
# 9         1959.200

# %%
car_sales["Passed road safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             4.5
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.2
# 5  Toyota  Green       NaN    4.0   $4,500    NaN             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    NaN             7.6
# 7   Honda   Blue       NaN    4.0      NaN    NaN             3.2
# 8  Toyota  White   60000.0    NaN      NaN    NaN             5.5
# 9     NaN  White   31600.0    4.0   $9,700    NaN             6.2
#
#    Total fuel used  Passed road safety
# 0        11253.225                True
# 1         8086.708                True
# 2              NaN                True
# 3          503.055                True
# 4        17473.790                True
# ...

# %% [markdown]
# # Remove a column

# %%
car_sales.drop("Total fuel used", axis=1)
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             4.5
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.2
# 5  Toyota  Green       NaN    4.0   $4,500    NaN             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    NaN             7.6
# 7   Honda   Blue       NaN    4.0      NaN    NaN             3.2
# 8  Toyota  White   60000.0    NaN      NaN    NaN             5.5
# 9     NaN  White   31600.0    4.0   $9,700    NaN             6.2
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# ...

# %% [markdown]
# # Sampling

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_sample = car_sales.sample(frac=1) # Float from 0.0 to 1.0
car_sales_sample
# Out:
#      Make Colour  Odometer  Doors    Price
# 3     BMW  Black   11179.0    5.0  $22,000
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 4  Nissan  White  213095.0    4.0   $3,500
# 0  Toyota  White  150043.0    4.0   $4,000
# 8  Toyota  White   60000.0    NaN      NaN
# 7   Honda   Blue       NaN    4.0      NaN
# 2  Toyota   Blue       NaN    3.0   $7,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_sample.reset_index(inplace=True, drop=True)
car_sales_sample
# Out:
#      Make Colour  Odometer  Doors    Price
# 0     BMW  Black   11179.0    5.0  $22,000
# 1  Toyota  Green       NaN    4.0   $4,500
# 2   Honda    NaN       NaN    4.0   $7,500
# 3  Nissan  White  213095.0    4.0   $3,500
# 4  Toyota  White  150043.0    4.0   $4,000
# 5  Toyota  White   60000.0    NaN      NaN
# 6   Honda   Blue       NaN    4.0      NaN
# 7  Toyota   Blue       NaN    3.0   $7,000
# 8   Honda    Red   87899.0    4.0   $5,000
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# # Lambda function

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales.Odometer = car_sales.Odometer.apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour    Odometer  Doors    Price
# 0  Toyota  White   93776.875    4.0   $4,000
# 1   Honda    Red   54936.875    4.0   $5,000
# 2  Toyota   Blue         NaN    3.0   $7,000
# 3     BMW  Black    6986.875    5.0  $22,000
# 4  Nissan  White  133184.375    4.0   $3,500
# 5  Toyota  Green         NaN    4.0   $4,500
# 6   Honda    NaN         NaN    4.0   $7,500
# 7   Honda   Blue         NaN    4.0      NaN
# 8  Toyota  White   37500.000    NaN      NaN
# 9     NaN  White   19750.000    4.0   $9,700
